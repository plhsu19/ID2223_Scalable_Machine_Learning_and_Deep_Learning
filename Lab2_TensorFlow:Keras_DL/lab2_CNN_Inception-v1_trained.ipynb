# %% [markdown]
# # Deep Learning with TensorFlow/Keras

# %% [markdown]
# Now that we have completed a project of Machine Learning with spark ML, in this assignment, we will be swithing to the context of Deep Learning with Tensorflow/Keras by two tasks:
# - Task1: Image Classification with CNN
# - Task2: Image captioning with a combination of CNN and RNN

# %% [markdown]
# ## Task 1: Going Deeper with convolutions

# %% [markdown]
# Before **Inception v1** (**GoogLeNet**), which is the winner of the **ILSVRC** (ImageNet Large Scale Visual Recognition Competition) in 2014, most popular CNNs just stacked convolution layers deeper and deeper, hoping to get better performance.
# The Inception network, however, uses a lot of tricks to improve performance in terms of speed and accuracy.
# Compared to other networks, **Inception v1** has significant improvement over **ZFNet** (the winner in 2013) and **AlexNet** (the winner in 2012), and has relatively lower error rate compared with the VGGNet.
#
# In this task, we will be implementing the inception architecture [in this paper](https://arxiv.org/abs/1409.4842) with TensorFlow/Keras.
#
# The goal of this task is to understand how to write code to build the model, as long as you can verify the correctness of the code (e.g., through Keras model summary), it is not necessary to train the model.

# %% [markdown]
# References:
#
#
#
# https://gist.github.com/joelouismarino/a2ede9ab3928f999575423b9887abd14#file-googlenet-py
#            https://www.analyticsvidhya.com/blog/2018/10/understanding-inception-network-from-scratch/

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
print(tf.__version__)
print(keras.__version__)
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# 1.15.0
# 2.2.4-tf

# %%
cifar10_dataset = tf.keras.datasets.cifar10

# %%
(x_train, y_train), (x_test, y_test) = cifar10_dataset.load_data()

# %%
print("shape of train x: ", x_train.shape)
print('shape of train y: ', y_train.shape)
print('shape of test x: ', x_test.shape)
print('shape of test y: ', y_test.shape)
print('type of train x: ', x_train.dtype)
print('type of train y: ', y_train.dtype)
row_num = 32
col_num = 32
# Out:
# shape of train x:  (50000, 32, 32, 3)
# shape of train y:  (50000, 1)
# shape of test x:  (10000, 32, 32, 3)
# shape of test y:  (10000, 1)
# type of train x:  uint8
# type of train y:  uint8

# %%
import matplotlib.pyplot as plt

plt.imshow(x_train[0])
plt.show()

# %%
print('Before normalization: ')
print('\t min of train is {}, max of train is {}'.format(np.min(x_train), np.max(x_train)))
print('\t min of test is {}, max of train is {}'.format(np.min(x_test), np.max(x_test)))

x_train = x_train / 255
x_test = x_test / 255

print('After normalization:')
print('\t min of train is {}, max of train is {}'.format(np.min(x_train), np.max(x_train)))
print('\t min of test is {}, max of test is {}'.format(np.min(x_test), np.max(x_test)))
# Out:
# Before normalization:
# 	 min of train is 0, max of train is 255
# 	 min of test is 0, max of train is 255
# After normalization:
# 	 min of train is 0.0, max of train is 1.0
# 	 min of test is 0.0, max of test is 1.0

# %%
print(x_train[0])
# Out:
# [[[0.23137255 0.24313725 0.24705882]
#   [0.16862745 0.18039216 0.17647059]
#   [0.19607843 0.18823529 0.16862745]
#   ...
#   [0.61960784 0.51764706 0.42352941]
#   [0.59607843 0.49019608 0.4       ]
#   [0.58039216 0.48627451 0.40392157]]
#
#  [[0.0627451  0.07843137 0.07843137]
#   [0.         0.         0.        ]
#   [0.07058824 0.03137255 0.        ]
#   ...
#   [0.48235294 0.34509804 0.21568627]
#   [0.46666667 0.3254902  0.19607843]
#   [0.47843137 0.34117647 0.22352941]]
#
#  [[0.09803922 0.09411765 0.08235294]
#   [0.0627451  0.02745098 0.        ]
#   [0.19215686 0.10588235 0.03137255]
#   ...
#   [0.4627451  0.32941176 0.19607843]
#   [0.47058824 0.32941176 0.19607843]
#   [0.42745098 0.28627451 0.16470588]]
#
#  ...
#
#  [[0.81568627 0.66666667 0.37647059]
#   [0.78823529 0.6        0.13333333]
#   [0.77647059 0.63137255 0.10196078]
#   ...
#   [0.62745098 0.52156863 0.2745098 ]
#   [0.21960784 0.12156863 0.02745098]
#   [0.20784314 0.13333333 0.07843137]]
#
#  [[0.70588235 0.54509804 0.37647059]
#   [0.67843137 0.48235294 0.16470588]
#   [0.72941176 0.56470588 0.11764706]
#   ...
#   [0.72156863 0.58039216 0.36862745]
#   [0.38039216 0.24313725 0.13333333]
#   [0.3254902  0.20784314 0.13333333]]
#
#  [[0.69411765 0.56470588 0.45490196]
#   [0.65882353 0.50588235 0.36862745]
#   [0.70196078 0.55686275 0.34117647]
#   ...
#   [0.84705882 0.72156863 0.54901961]
#   [0.59215686 0.4627451  0.32941176]
#   [0.48235294 0.36078431 0.28235294]]]

# %%
from tensorflow.keras.layers import Input, Dense, Conv2D, MaxPooling2D, AveragePooling2D, Dropout, Flatten, Concatenate, Reshape, GlobalAveragePooling2D 
from tensorflow.keras.models import Model
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import SGD

# %% [markdown]
# ## Build the Inception-v1 model

# %%
def inception(input_tensor, filters_1x1, filters_3x3_reduce, filters_3x3, filters_5x5_reduce, filters_5x5, filters_pool_proj, 
              Name = None):
    
    conv_1x1 = Conv2D(filters_1x1, (1,1), padding = 'same', activation = 'relu', name = (Name + '/conv_1x1'))(input_tensor)
    
    conv_3x3_reduce = Conv2D(filters_3x3_reduce, (1, 1), padding = 'same', activation = 'relu', name = (Name + '/conv_3x3_reduce'))(input_tensor)
    conv_3x3 = Conv2D(filters_3x3, (3, 3), padding = 'same', activation = 'relu', name = (Name + '/conv_3x3'))(conv_3x3_reduce)
 
    conv_5x5_reduce = Conv2D(filters_5x5_reduce, (1, 1), padding = 'same', activation = 'relu', name = (Name + '/conv_5x5_reduce'))(input_tensor)
    conv_5x5 = Conv2D(filters_5x5, (5, 5), padding = 'same', activation = 'relu', name = (Name + '/conv_5x5'))(conv_5x5_reduce)
    
    pool = MaxPooling2D((3, 3), strides = (1, 1), padding = 'same', name = (Name + '/pool'))(input_tensor)
    pool_proj = Conv2D(filters_pool_proj, (1, 1), padding = 'same', activation = 'relu', name = (Name + '/pool_proj'))(pool)
    
    output = Concatenate(axis = 3, name = (Name + '_output'))([conv_1x1, conv_3x3, conv_5x5, pool_proj])
    return output

# %%
#Input layer
input_layer = Input(shape = (row_num, col_num, 3), name = 'input_layer')

#Stem module
conv1_7x7 = Conv2D(64, (7, 7), strides = (2, 2), padding = 'same', activation = 'relu', 
                   name = 'conv1_7x7/s2')(input_layer) 
pool1_3x3 = MaxPooling2D((3, 3), strides = (2, 2), padding = 'same', name = 'pool1/3x3_s2')(conv1_7x7)
conv2_3x3_reduce = Conv2D(64, (1, 1), padding = 'same', activation = 'relu', 
                          name = 'conv2/3x3_reduce')(pool1_3x3)
conv2_3x3 = Conv2D(192, (3, 3), padding = 'same', activation = 'relu', 
                   name = 'conv2/3x3')(conv2_3x3_reduce)
pool2_3x3 = MaxPooling2D((3, 3), strides = (2, 2), padding = 'same', name = 'pool2/3x3_s2')(conv2_3x3)

#Inception 3a & 3b
inception_3a = inception(pool2_3x3, filters_1x1 = 64, filters_3x3_reduce = 96, 
                         filters_3x3 = 128, filters_5x5_reduce = 16, filters_5x5 = 32, 
                         filters_pool_proj = 32, Name = 'incep_3a')
inception_3b = inception(inception_3a, filters_1x1 = 128, filters_3x3_reduce = 128, 
                         filters_3x3 = 192, filters_5x5_reduce = 32, filters_5x5 = 96, 
                         filters_pool_proj = 64, Name = 'incep_3b')

#max pool & inception 4a
pool3_3x3 = MaxPooling2D((3, 3), strides = (2, 2), padding = 'same', name = 'pool3/3x3_s2')(inception_3b)
inception_4a = inception(pool3_3x3, filters_1x1 = 192, filters_3x3_reduce = 96, 
                         filters_3x3 = 208, filters_5x5_reduce = 16, filters_5x5 = 48, 
                         filters_pool_proj = 64, Name = 'incep_4a')


#aux1 brach
#aux1_ave_pool = AveragePooling2D((5, 5), strides = (3, 3), name = 'aux1/ave_pool')(inception_4a)
aux1_conv = Conv2D(128, (1, 1), padding = 'same', activation = 'relu', 
                    name = 'aux1/conv')(inception_4a)
aux1_flat = Flatten()(aux1_conv)
aux1_fc = Dense(1024, activation = 'relu', name = 'aux1/fc')(aux1_flat)
aux1_dropout = Dropout(rate = 0.7)(aux1_fc)
aux1_output = Dense(10, activation = 'softmax', name = 'aux1/classifier')(aux1_dropout)

#inception 4b & 4c & 4d
inception_4b = inception(inception_4a, filters_1x1 = 160, filters_3x3_reduce = 112, 
                         filters_3x3 = 224, filters_5x5_reduce = 24, filters_5x5 = 64, 
                         filters_pool_proj = 64, Name = 'incep_4b')
inception_4c = inception(inception_4b, filters_1x1 = 128, filters_3x3_reduce = 128, 
                         filters_3x3 = 256, filters_5x5_reduce = 24, filters_5x5 = 64, 
                         filters_pool_proj = 64, Name = 'incep_4c')
inception_4d = inception(inception_4c, filters_1x1 = 112, filters_3x3_reduce = 144, 
                         filters_3x3 = 288, filters_5x5_reduce = 32, filters_5x5 = 64, 
                         filters_pool_proj = 64, Name = 'incep_4d')

#aux2 branch
#aux2_ave_pool = AveragePooling2D((5, 5), strides = (3, 3), name = 'aux2/ave_pool')(inception_4d)
aux2_conv = Conv2D(128, (1, 1), padding = 'same', activation = 'relu', 
                    name = 'aux2/conv')(inception_4d)
aux2_flat = Flatten()(aux2_conv)
aux2_fc = Dense(1024, activation = 'relu', name = 'aux2/fc')(aux2_flat)
aux2_dropout = Dropout(rate = 0.7)(aux2_fc)
aux2_output = Dense(10, activation = 'softmax', name = 'aux2/classifier')(aux2_dropout)

#inception 4e & max pool
inception_4e = inception(inception_4d, filters_1x1 = 256, filters_3x3_reduce = 160, 
                         filters_3x3 = 320, filters_5x5_reduce = 32, filters_5x5 = 128, 
                         filters_pool_proj = 128, Name = 'incep_4e')
pool4_3x3 = MaxPooling2D((3, 3), strides = (2, 2), padding = 'same', name = 'pool4/3x3_s2')(inception_4e)

#inception 5a & 5b
inception_5a = inception(pool4_3x3, filters_1x1 = 256, filters_3x3_reduce = 160, 
                         filters_3x3 = 320, filters_5x5_reduce = 32, filters_5x5 = 128, 
                         filters_pool_proj = 128, Name = 'incep_5a')

inception_5b = inception(inception_5a, filters_1x1 = 384, filters_3x3_reduce = 192, 
                         filters_3x3 = 384, filters_5x5_reduce = 48, filters_5x5 = 128, 
                         filters_pool_proj = 128, Name = 'incep_5b')

#main output
#ave_pool = AveragePooling2D((7, 7), strides = (1, 1), name = 'ave_pool')(inception_5b)
flat = Flatten()(inception_5b)
dropout = Dropout(rate = 0.4)(flat)
output = Dense(10, activation = 'softmax', name = 'classifier')(dropout)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:Large dropout rate: 0.7 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# WARNING:tensorflow:Large dropout rate: 0.7 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.

# %%
model = Model(input_layer, [output, aux1_output, aux2_output], name = 'Inception_V1')

#print model layers
model.summary()

#compile model
sgd = SGD(lr = 0.1, decay = 1e-6, momentum = 0.9, nesterov = True)
model.compile(optimizer = sgd, 
              loss = ["sparse_categorical_crossentropy", "sparse_categorical_crossentropy", "sparse_categorical_crossentropy"], 
              loss_weights = [1, 0.3, 0.3], metrics = ["accuracy"])
# Out:
# Model: "Inception_V1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_layer (InputLayer)        [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv1_7x7/s2 (Conv2D)           (None, 16, 16, 64)   9472        input_layer[0][0]
# __________________________________________________________________________________________________
# pool1/3x3_s2 (MaxPooling2D)     (None, 8, 8, 64)     0           conv1_7x7/s2[0][0]
# __________________________________________________________________________________________________
# conv2/3x3_reduce (Conv2D)       (None, 8, 8, 64)     4160        pool1/3x3_s2[0][0]
# __________________________________________________________________________________________________
# conv2/3x3 (Conv2D)              (None, 8, 8, 192)    110784      conv2/3x3_reduce[0][0]
# __________________________________________________________________________________________________
# pool2/3x3_s2 (MaxPooling2D)     (None, 4, 4, 192)    0           conv2/3x3[0][0]
# __________________________________________________________________________________________________
# incep_3a/conv_3x3_reduce (Conv2 (None, 4, 4, 96)     18528       pool2/3x3_s2[0][0]
# __________________________________________________________________________________________________
# incep_3a/conv_5x5_reduce (Conv2 (None, 4, 4, 16)     3088        pool2/3x3_s2[0][0]
# __________________________________________________________________________________________________
# incep_3a/pool (MaxPooling2D)    (None, 4, 4, 192)    0           pool2/3x3_s2[0][0]
# __________________________________________________________________________________________________
# incep_3a/conv_1x1 (Conv2D)      (None, 4, 4, 64)     12352       pool2/3x3_s2[0][0]
# __________________________________________________________________________________________________
# incep_3a/conv_3x3 (Conv2D)      (None, 4, 4, 128)    110720      incep_3a/conv_3x3_reduce[0][0]
# __________________________________________________________________________________________________
# incep_3a/conv_5x5 (Conv2D)      (None, 4, 4, 32)     12832       incep_3a/conv_5x5_reduce[0][0]
# __________________________________________________________________________________________________
# incep_3a/pool_proj (Conv2D)     (None, 4, 4, 32)     6176        incep_3a/pool[0][0]
# __________________________________________________________________________________________________
# incep_3a_output (Concatenate)   (None, 4, 4, 256)    0           incep_3a/conv_1x1[0][0]
#                                                                  incep_3a/conv_3x3[0][0]
#                                                                  incep_3a/conv_5x5[0][0]
#                                                                  incep_3a/pool_proj[0][0]
# __________________________________________________________________________________________________
# incep_3b/conv_3x3_reduce (Conv2 (None, 4, 4, 128)    32896       incep_3a_output[0][0]
# __________________________________________________________________________________________________
# incep_3b/conv_5x5_reduce (Conv2 (None, 4, 4, 32)     8224        incep_3a_output[0][0]
# __________________________________________________________________________________________________
# incep_3b/pool (MaxPooling2D)    (None, 4, 4, 256)    0           incep_3a_output[0][0]
# __________________________________________________________________________________________________
# incep_3b/conv_1x1 (Conv2D)      (None, 4, 4, 128)    32896       incep_3a_output[0][0]
# __________________________________________________________________________________________________
# incep_3b/conv_3x3 (Conv2D)      (None, 4, 4, 192)    221376      incep_3b/conv_3x3_reduce[0][0]
# __________________________________________________________________________________________________
# incep_3b/conv_5x5 (Conv2D)      (None, 4, 4, 96)     76896       incep_3b/conv_5x5_reduce[0][0]
# __________________________________________________________________________________________________
# incep_3b/pool_proj (Conv2D)     (None, 4, 4, 64)     16448       incep_3b/pool[0][0]
# __________________________________________________________________________________________________
# incep_3b_output (Concatenate)   (None, 4, 4, 480)    0           incep_3b/conv_1x1[0][0]
#                                                                  incep_3b/conv_3x3[0][0]
#                                                                  incep_3b/conv_5x5[0][0]
#                                                                  incep_3b/pool_proj[0][0]
# __________________________________________________________________________________________________
# pool3/3x3_s2 (MaxPooling2D)     (None, 2, 2, 480)    0           incep_3b_output[0][0]
# __________________________________________________________________________________________________
# incep_4a/conv_3x3_reduce (Conv2 (None, 2, 2, 96)     46176       pool3/3x3_s2[0][0]
# __________________________________________________________________________________________________
# incep_4a/conv_5x5_reduce (Conv2 (None, 2, 2, 16)     7696        pool3/3x3_s2[0][0]
# __________________________________________________________________________________________________
# incep_4a/pool (MaxPooling2D)    (None, 2, 2, 480)    0           pool3/3x3_s2[0][0]
# __________________________________________________________________________________________________
# incep_4a/conv_1x1 (Conv2D)      (None, 2, 2, 192)    92352       pool3/3x3_s2[0][0]
# __________________________________________________________________________________________________
# incep_4a/conv_3x3 (Conv2D)      (None, 2, 2, 208)    179920      incep_4a/conv_3x3_reduce[0][0]
# __________________________________________________________________________________________________
# incep_4a/conv_5x5 (Conv2D)      (None, 2, 2, 48)     19248       incep_4a/conv_5x5_reduce[0][0]
# __________________________________________________________________________________________________
# incep_4a/pool_proj (Conv2D)     (None, 2, 2, 64)     30784       incep_4a/pool[0][0]
# __________________________________________________________________________________________________
# incep_4a_output (Concatenate)   (None, 2, 2, 512)    0           incep_4a/conv_1x1[0][0]
#                                                                  incep_4a/conv_3x3[0][0]
#                                                                  incep_4a/conv_5x5[0][0]
#                                                                  incep_4a/pool_proj[0][0]
# __________________________________________________________________________________________________
# incep_4b/conv_3x3_reduce (Conv2 (None, 2, 2, 112)    57456       incep_4a_output[0][0]
# __________________________________________________________________________________________________
# incep_4b/conv_5x5_reduce (Conv2 (None, 2, 2, 24)     12312       incep_4a_output[0][0]
# __________________________________________________________________________________________________
# incep_4b/pool (MaxPooling2D)    (None, 2, 2, 512)    0           incep_4a_output[0][0]
# __________________________________________________________________________________________________
# incep_4b/conv_1x1 (Conv2D)      (None, 2, 2, 160)    82080       incep_4a_output[0][0]
# __________________________________________________________________________________________________
# incep_4b/conv_3x3 (Conv2D)      (None, 2, 2, 224)    226016      incep_4b/conv_3x3_reduce[0][0]
# __________________________________________________________________________________________________
# incep_4b/conv_5x5 (Conv2D)      (None, 2, 2, 64)     38464       incep_4b/conv_5x5_reduce[0][0]
# __________________________________________________________________________________________________
# incep_4b/pool_proj (Conv2D)     (None, 2, 2, 64)     32832       incep_4b/pool[0][0]
# __________________________________________________________________________________________________
# incep_4b_output (Concatenate)   (None, 2, 2, 512)    0           incep_4b/conv_1x1[0][0]
#                                                                  incep_4b/conv_3x3[0][0]
#                                                                  incep_4b/conv_5x5[0][0]
#                                                                  incep_4b/pool_proj[0][0]
# __________________________________________________________________________________________________
# incep_4c/conv_3x3_reduce (Conv2 (None, 2, 2, 128)    65664       incep_4b_output[0][0]
# __________________________________________________________________________________________________
# incep_4c/conv_5x5_reduce (Conv2 (None, 2, 2, 24)     12312       incep_4b_output[0][0]
# __________________________________________________________________________________________________
# incep_4c/pool (MaxPooling2D)    (None, 2, 2, 512)    0           incep_4b_output[0][0]
# __________________________________________________________________________________________________
# incep_4c/conv_1x1 (Conv2D)      (None, 2, 2, 128)    65664       incep_4b_output[0][0]
# __________________________________________________________________________________________________
# incep_4c/conv_3x3 (Conv2D)      (None, 2, 2, 256)    295168      incep_4c/conv_3x3_reduce[0][0]
# __________________________________________________________________________________________________
# incep_4c/conv_5x5 (Conv2D)      (None, 2, 2, 64)     38464       incep_4c/conv_5x5_reduce[0][0]
# __________________________________________________________________________________________________
# incep_4c/pool_proj (Conv2D)     (None, 2, 2, 64)     32832       incep_4c/pool[0][0]
# __________________________________________________________________________________________________
# incep_4c_output (Concatenate)   (None, 2, 2, 512)    0           incep_4c/conv_1x1[0][0]
#                                                                  incep_4c/conv_3x3[0][0]
#                                                                  incep_4c/conv_5x5[0][0]
#                                                                  incep_4c/pool_proj[0][0]
# __________________________________________________________________________________________________
# incep_4d/conv_3x3_reduce (Conv2 (None, 2, 2, 144)    73872       incep_4c_output[0][0]
# __________________________________________________________________________________________________
# incep_4d/conv_5x5_reduce (Conv2 (None, 2, 2, 32)     16416       incep_4c_output[0][0]
# __________________________________________________________________________________________________
# incep_4d/pool (MaxPooling2D)    (None, 2, 2, 512)    0           incep_4c_output[0][0]
# __________________________________________________________________________________________________
# incep_4d/conv_1x1 (Conv2D)      (None, 2, 2, 112)    57456       incep_4c_output[0][0]
# __________________________________________________________________________________________________
# incep_4d/conv_3x3 (Conv2D)      (None, 2, 2, 288)    373536      incep_4d/conv_3x3_reduce[0][0]
# __________________________________________________________________________________________________
# incep_4d/conv_5x5 (Conv2D)      (None, 2, 2, 64)     51264       incep_4d/conv_5x5_reduce[0][0]
# __________________________________________________________________________________________________
# incep_4d/pool_proj (Conv2D)     (None, 2, 2, 64)     32832       incep_4d/pool[0][0]
# __________________________________________________________________________________________________
# incep_4d_output (Concatenate)   (None, 2, 2, 528)    0           incep_4d/conv_1x1[0][0]
#                                                                  incep_4d/conv_3x3[0][0]
#                                                                  incep_4d/conv_5x5[0][0]
#                                                                  incep_4d/pool_proj[0][0]
# __________________________________________________________________________________________________
# incep_4e/conv_3x3_reduce (Conv2 (None, 2, 2, 160)    84640       incep_4d_output[0][0]
# __________________________________________________________________________________________________
# incep_4e/conv_5x5_reduce (Conv2 (None, 2, 2, 32)     16928       incep_4d_output[0][0]
# __________________________________________________________________________________________________
# incep_4e/pool (MaxPooling2D)    (None, 2, 2, 528)    0           incep_4d_output[0][0]
# __________________________________________________________________________________________________
# incep_4e/conv_1x1 (Conv2D)      (None, 2, 2, 256)    135424      incep_4d_output[0][0]
# __________________________________________________________________________________________________
# incep_4e/conv_3x3 (Conv2D)      (None, 2, 2, 320)    461120      incep_4e/conv_3x3_reduce[0][0]
# __________________________________________________________________________________________________
# incep_4e/conv_5x5 (Conv2D)      (None, 2, 2, 128)    102528      incep_4e/conv_5x5_reduce[0][0]
# __________________________________________________________________________________________________
# incep_4e/pool_proj (Conv2D)     (None, 2, 2, 128)    67712       incep_4e/pool[0][0]
# __________________________________________________________________________________________________
# incep_4e_output (Concatenate)   (None, 2, 2, 832)    0           incep_4e/conv_1x1[0][0]
#                                                                  incep_4e/conv_3x3[0][0]
#                                                                  incep_4e/conv_5x5[0][0]
#                                                                  incep_4e/pool_proj[0][0]
# __________________________________________________________________________________________________
# pool4/3x3_s2 (MaxPooling2D)     (None, 1, 1, 832)    0           incep_4e_output[0][0]
# __________________________________________________________________________________________________
# incep_5a/conv_3x3_reduce (Conv2 (None, 1, 1, 160)    133280      pool4/3x3_s2[0][0]
# __________________________________________________________________________________________________
# incep_5a/conv_5x5_reduce (Conv2 (None, 1, 1, 32)     26656       pool4/3x3_s2[0][0]
# __________________________________________________________________________________________________
# incep_5a/pool (MaxPooling2D)    (None, 1, 1, 832)    0           pool4/3x3_s2[0][0]
# __________________________________________________________________________________________________
# incep_5a/conv_1x1 (Conv2D)      (None, 1, 1, 256)    213248      pool4/3x3_s2[0][0]
# __________________________________________________________________________________________________
# incep_5a/conv_3x3 (Conv2D)      (None, 1, 1, 320)    461120      incep_5a/conv_3x3_reduce[0][0]
# __________________________________________________________________________________________________
# incep_5a/conv_5x5 (Conv2D)      (None, 1, 1, 128)    102528      incep_5a/conv_5x5_reduce[0][0]
# __________________________________________________________________________________________________
# incep_5a/pool_proj (Conv2D)     (None, 1, 1, 128)    106624      incep_5a/pool[0][0]
# __________________________________________________________________________________________________
# incep_5a_output (Concatenate)   (None, 1, 1, 832)    0           incep_5a/conv_1x1[0][0]
#                                                                  incep_5a/conv_3x3[0][0]
#                                                                  incep_5a/conv_5x5[0][0]
#                                                                  incep_5a/pool_proj[0][0]
# __________________________________________________________________________________________________
# incep_5b/conv_3x3_reduce (Conv2 (None, 1, 1, 192)    159936      incep_5a_output[0][0]
# __________________________________________________________________________________________________
# incep_5b/conv_5x5_reduce (Conv2 (None, 1, 1, 48)     39984       incep_5a_output[0][0]
# __________________________________________________________________________________________________
# incep_5b/pool (MaxPooling2D)    (None, 1, 1, 832)    0           incep_5a_output[0][0]
# __________________________________________________________________________________________________
# incep_5b/conv_1x1 (Conv2D)      (None, 1, 1, 384)    319872      incep_5a_output[0][0]
# __________________________________________________________________________________________________
# incep_5b/conv_3x3 (Conv2D)      (None, 1, 1, 384)    663936      incep_5b/conv_3x3_reduce[0][0]
# __________________________________________________________________________________________________
# incep_5b/conv_5x5 (Conv2D)      (None, 1, 1, 128)    153728      incep_5b/conv_5x5_reduce[0][0]
# __________________________________________________________________________________________________
# incep_5b/pool_proj (Conv2D)     (None, 1, 1, 128)    106624      incep_5b/pool[0][0]
# __________________________________________________________________________________________________
# aux1/conv (Conv2D)              (None, 2, 2, 128)    65664       incep_4a_output[0][0]
# __________________________________________________________________________________________________
# aux2/conv (Conv2D)              (None, 2, 2, 128)    67712       incep_4d_output[0][0]
# __________________________________________________________________________________________________
# incep_5b_output (Concatenate)   (None, 1, 1, 1024)   0           incep_5b/conv_1x1[0][0]
#                                                                  incep_5b/conv_3x3[0][0]
#                                                                  incep_5b/conv_5x5[0][0]
#                                                                  incep_5b/pool_proj[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 512)          0           aux1/conv[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 512)          0           aux2/conv[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 1024)         0           incep_5b_output[0][0]
# __________________________________________________________________________________________________
# aux1/fc (Dense)                 (None, 1024)         525312      flatten[0][0]
# __________________________________________________________________________________________________
# aux2/fc (Dense)                 (None, 1024)         525312      flatten_1[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 1024)         0           flatten_2[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 1024)         0           aux1/fc[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 1024)         0           aux2/fc[0][0]
# __________________________________________________________________________________________________
# classifier (Dense)              (None, 10)           10250       dropout_2[0][0]
# __________________________________________________________________________________________________
# aux1/classifier (Dense)         (None, 10)           10250       dropout[0][0]
# __________________________________________________________________________________________________
# aux2/classifier (Dense)         (None, 10)           10250       dropout_1[0][0]
# ==================================================================================================
# Total params: 7,188,302
# Trainable params: 7,188,302
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
keras.utils.plot_model(model, 'inception_model.png', show_shapes = True)

# %%
#train the model
batch_size = 10000
epochs = 1

history = model.fit(x_train, [y_train, y_train, y_train], batch_size = batch_size, 
                    epochs = epochs, validation_data = (x_test, [y_test, y_test, y_test]))
# Out:
# Train on 50000 samples, validate on 10000 samples
# 50000/50000 [==============================] - 621s 12ms/sample - loss: 3.6841 - classifier_loss: 2.3025 - aux1/classifier_loss: 2.3025 - aux2/classifier_loss: 2.3027 - classifier_acc: 0.1007 - aux1/classifier_acc: 0.1003 - aux2/classifier_acc: 0.1005 - val_loss: 3.6836 - val_classifier_loss: 2.3024 - val_aux1/classifier_loss: 2.3016 - val_aux2/classifier_loss: 2.3026 - val_classifier_acc: 0.1013 - val_aux1/classifier_acc: 0.1000 - val_aux2/classifier_acc: 0.1000

# %%
#predict
classification = model.predict(x_test)
print(classification[0][5])
#print(len(classification))
#print(type(y_test))
print('test label: ', y_test[5])
#print('\t min of test label is {}, max of test label is {}'.format(np.min(y_test), np.max(y_test)))
print('test prediction: ', np.argmax(classification[0][5]))
# Out:
# [0.10013444 0.099859   0.10002979 0.09996779 0.09988324 0.09997128
#  0.10000576 0.10006826 0.10029326 0.09978718]
# test label:  [6]
# test prediction:  8

# %% [markdown]
# ## Task 2: Show and Tell: A Neural Image Caption Generator

# %% [markdown]
# Automatically describing the content of an image is a fundamental problem in AI that connects *computer vision* and *natural language processing*.
# In this task, we will be looking into how we can use CNNs and RNNs to build an Image Caption Generator.
#
# Specifically, you will be implementing and training the model [in this paper](https://arxiv.org/abs/1411.4555) with TensorFlow/Keras on one of the datasets mentioned in the paper.
#
# To lighten the burden on training the network, you can use any pretrained network in [tf.keras.applications](https://www.tensorflow.org/api_docs/python/tf/keras/applications).

# %%
# code here
